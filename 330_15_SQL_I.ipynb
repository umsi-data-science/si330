# %% [markdown]
# # SQL Outline
#
# ## Day 1
#
# * AWS Overview
#   * EC2, RDS
#
# * Tasks
#   * log into AWS Console
#   * create EC2 instance
#     * yum install mysql
#     * wget .sql
#
# ## Day 2
#
# * RDS
# * MySQL
#
# * Tasks
#   * create RDS instance
#   * load SQL file from EC2
#   * browse with MySQLWorkbench
#
# ## Day 3
#
# * pymysql
#
# * Tasks
#   * query goodreads
#
# ## Day 4
#
# * BigQuery, Redshift?

# %%
import pymysql

# %%
connection = pymysql.connect(host='si330-cteplovs.csa8wfwjpfhl.us-east-1.rds.amazonaws.com',
                             user='cteplovs',
                             password='cteplovs',
                             db='si330_cteplovs',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
    cursor.execute('select * from books where original_title like "%Hunger%"')
    results = cursor.fetchall()
    for result in results:
        print(result['original_title'])
# Out:
# The Hunger Games
# The Hunger Games Box Set
# Hunger
# A Hunger Like No Other
# Hunger Makes Me a Modern Girl

# %%
import pandas as pd

# %%
df = pd.read_sql('select * from books where original_title like "%Hunger%"',con=connection)

# %%
df
# Out:
#    book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0        1            2767052       2767052   2792775          272
# 1      507            7938275       7938275  11349083           78
# 2     1820            5047880       5047880   5114483           47
# 3     3115              14384         14384     16422           52
# 4     5663           25065629      25065629  44749816           17
#
#          isbn        isbn13            authors  original_publication_year  \
# 0   439023483  9.780440e+12    Suzanne Collins                       2008
# 1   545265355  9.780550e+12    Suzanne Collins                       2010
# 2    61449067  9.780060e+12     Michael  Grant                       2009
# 3  1416509879  9.781420e+12       Kresley Cole                       2006
# 4  1594486638  9.781590e+12  Carrie Brownstein                       2015
#
#                   original_title  \
# 0               The Hunger Games
# 1       The Hunger Games Box Set
# ...

# %%
import boto3

# %%
s3 = boto3.resource('s3')
